# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import pickle
import json

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Data Science\Datasets\Cellphone.csv")
df
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq
# 0           203   2357    10   135.0         5.20  424         8     1.350  \
# 1           880   1749    10   125.0         4.00  233         2     1.300
# 2            40   1916    10   110.0         4.70  312         4     1.200
# 3            99   1315    11   118.5         4.00  233         2     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# ..          ...    ...   ...     ...          ...  ...       ...       ...
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem    ram  RearCam  Front_Cam  battery  thickness
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %% [markdown]
# ### EDA

# %%
df.drop("Product_id",axis = 1,inplace = True)

# %%
df
# Out:
#      Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  internal mem
# 0     2357    10   135.0         5.20  424         8     1.350          16.0  \
# 1     1749    10   125.0         4.00  233         2     1.300           4.0
# 2     1916    10   110.0         4.70  312         4     1.200           8.0
# 3     1315    11   118.5         4.00  233         2     1.300           4.0
# 4     1749    11   125.0         4.00  233         2     1.300           4.0
# ..     ...   ...     ...          ...  ...       ...       ...           ...
# 156   3551  4638   178.0         5.46  538         4     1.875         128.0
# 157   3211  8016   170.0         5.50  534         4     1.975         128.0
# 158   3260  8809   150.0         5.50  401         8     2.200          64.0
# 159   3211  8946   170.0         5.50  534         4     1.975         128.0
# 160   2536  9807   202.0         6.00  367         8     1.500          16.0
#
# ...

# %%
df.rename(columns = {'cpu core':'cpu_core','cpu freq':'cpu_freq','internal mem':'internal_mem'}, inplace = True)

# %%
df
# Out:
#      Price  Sale  weight  resoloution  ppi  cpu_core  cpu_freq  internal_mem
# 0     2357    10   135.0         5.20  424         8     1.350          16.0  \
# 1     1749    10   125.0         4.00  233         2     1.300           4.0
# 2     1916    10   110.0         4.70  312         4     1.200           8.0
# 3     1315    11   118.5         4.00  233         2     1.300           4.0
# 4     1749    11   125.0         4.00  233         2     1.300           4.0
# ..     ...   ...     ...          ...  ...       ...       ...           ...
# 156   3551  4638   178.0         5.46  538         4     1.875         128.0
# 157   3211  8016   170.0         5.50  534         4     1.975         128.0
# 158   3260  8809   150.0         5.50  401         8     2.200          64.0
# 159   3211  8946   170.0         5.50  534         4     1.975         128.0
# 160   2536  9807   202.0         6.00  367         8     1.500          16.0
#
# ...

# %% [markdown]
# ### Model Training

# %%
x = df.drop("Price",axis = True)
y = df["Price"]

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state=13)

# %%
linear_reg = LinearRegression()
linear_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Evaluation

# %%
y_pred = linear_reg.predict(x_test)

mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
print("RMSE",rmse)

mae = mean_absolute_error(y_test,y_pred)
print("MAE",mae)

r2_value = r2_score(y_test,y_pred)
print("R-Squared :",r2_value)
# Out:
# RMSE 174.17693919993167
# MAE 133.93259905107757
# R-Squared : 0.9347650697493228

# %%
y_pred_train = linear_reg.predict(x_train)

mse = mean_squared_error(y_train,y_pred_train)
rmse = np.sqrt(mse)
print("RMSE",rmse)

mae = mean_absolute_error(y_train,y_pred_train)
print("MAE",mae)

r2_value = r2_score(y_train,y_pred_train)
print("R-Squared :",r2_value)
# Out:
# RMSE 164.66738490827424
# MAE 137.6855005885626
# R-Squared : 0.955916161941781

# %% [markdown]
# ### Single row testing

# %%
x_test[10:11]
# Out:
#      Sale  weight  resoloution  ppi  cpu_core  cpu_freq  internal_mem  ram
# 142  1530   152.0          5.2  424         4       2.5          16.0  3.0  \
#
#      RearCam  Front_Cam  battery  thickness
# 142     20.7        2.2     3100        7.3

# %%
linear_reg.predict(x_test[10:11])[0]
# Out:
# 2524.2761470116675

# %%
Sale = 10
weight = 186.0
resoloution = 6.3
ppi = 409
cpu_core = 8
cpu_freq = 2.0
internal_mem = 64
ram = 4
RearCam = 12
Front_Cam = 13
battery = 4000
thickness = 8.1

# %%
column_names = x.columns.tolist()
column_names
# Out:
# ['Sale',
#  'weight',
#  'resoloution',
#  'ppi',
#  'cpu_core',
#  'cpu_freq',
#  'internal_mem',
#  'ram',
#  'RearCam',
#  'Front_Cam',
#  'battery',
#  'thickness']

# %%
x.shape[1]
# Out:
# 12

# %%
linear_reg.n_features_in_
# Out:
# 12

# %%
Sale = 10
weight = 186.0
resoloution = 6.3
ppi = 409
cpu_core = 8
cpu_freq = 2.0
internal_mem = 64
ram = 4
RearCam = 48
Front_Cam = 13
battery = 4000
thickness = 8.1

test_array = np.zeros([1,linear_reg.n_features_in_])
test_array[0,0] = Sale
test_array[0,1] = weight
test_array[0,2] = resoloution
test_array[0,3] = ppi
test_array[0,4] = cpu_core
test_array[0,5] = cpu_freq
test_array[0,6] = internal_mem
test_array[0,7] = ram
test_array[0,8] = RearCam
test_array[0,9] = Front_Cam
test_array[0,10] = battery
test_array[0,11] = thickness


predicted_price = np.around(linear_reg.predict(test_array)[0],3)
predicted_price
# Out:
# 3288.322

# %%
with open('linear_regression.pkl','wb') as f:
    pickle.dump(linear_reg, f)

# %%
project_data = {"Column Names" : column_names}

with open('proj_data.json','w') as f:
    json.dump(project_data, f)
